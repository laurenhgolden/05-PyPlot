# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - In reviewing the data, it is clear that Capomulin about as effective as Ramicane, but more effective than Infubinol and Ceftamin, when comparing the final tumor sizes across the different drugs. Moreover, these results can be verified because more mice were tested for Capomulin and Ramicane than the other drugs tested. It also had a lower standard deviation and variance than the other drugs, meaning its results provided more stastical consistency.
#
# - With that said, the average tumor size is relative to the average size of the mouse. Therefore, further analysis is required to ensure that the average weight of the mice taking Capomulin was similar to the other drugs. If smaller mice were receiving the Capomulin treatment, this may have inadvertently skewed the results.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as stats

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
mouse_merged = pd.merge(study_results, mouse_metadata, on = "Mouse ID", how = "left")

# Display the data table for preview 
mouse_merged.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
len(mouse_merged["Mouse ID"].unique())
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicates_df = mouse_merged[mouse_merged.duplicated(subset=["Mouse ID", "Timepoint"], keep = False)]
duplicates_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
#
#          Sex  Age_months  Weight (g)
# 107   Female          21          26
# 137   Female          21          26
# ...

# %%
# Optional: Get all the data for the duplicate mouse ID. 
g989 = duplicates_dropped.loc[duplicates_dropped["Mouse ID"]=="g989"]
g989
# Out:
# Empty DataFrame
# Columns: [Mouse ID, Timepoint, Tumor Volume (mm3), Metastatic Sites, Drug Regimen, Sex, Age_months, Weight (g)]
# Index: []

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
duplicates_dropped = duplicates_dropped.loc[duplicates_dropped["Mouse ID"]!="g989"]
duplicates_dropped
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice in the clean DataFrame.
len(duplicates_dropped["Mouse ID"].unique())
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.
tumor_mean = duplicates_dropped.groupby(["Drug Regimen"]).mean()["Tumor Volume (mm3)"]
tumor_median = duplicates_dropped.groupby(["Drug Regimen"]).median()["Tumor Volume (mm3)"]
tumor_var = duplicates_dropped.groupby(["Drug Regimen"]).var()["Tumor Volume (mm3)"]
tumor_std = duplicates_dropped.groupby(["Drug Regimen"]).std()["Tumor Volume (mm3)"]
tumor_sem = duplicates_dropped.groupby(["Drug Regimen"]).sem()["Tumor Volume (mm3)"]

summary_statistics = pd.DataFrame({
    "Mean Tumor Volume": tumor_mean,
    "Median Tumor Volume": tumor_median,
    "Tumor Volume Variance": tumor_var,
    "Tumor Volume Std. Dev.": tumor_std,
    "Tumor Volume Std. Err.": tumor_sem
})

summary_statistics
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
# and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line.
tumor_ag = duplicates_dropped.groupby("Drug Regimen").agg({"Tumor Volume (mm3)": ['mean', 'median', 'var', 'std', 'sem']})
tumor_ag
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
mice_tested = duplicates_dropped.groupby(["Drug Regimen"]).count()["Timepoint"]
mice_sorted = mice_tested.sort_values(ascending = False)
#mice_sorted
figure1 = mice_sorted.plot(kind = "bar", facecolor = "blue", figsize = (5,3),
                          title= "Total Mice Tested by Drug Regimen",
                          xlabel = "Drug Regimen",
                          ylabel = "Number of Mice Tested")
plt.show()

# %%
# Take Series and convert into lists for pyplot calculations using: index_list = list(df.index.values) 
# and Series.values.tolist(),
index_list = list(mice_sorted.index.values)
column_list = mice_sorted.values.tolist()

# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.
plt.bar(index_list, column_list, color = "b", alpha=0.5, align = "center")
plt.title("Total Mice Tested by Drug Regimen")
plt.xlabel("Druge Regimen")
plt.ylabel("Number of Mice Tested")

# Configure x-tick rotation
plt.xticks(rotation = 90, ha="center")
# Show plot
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
gender_dist = duplicates_dropped["Sex"].value_counts()
gender_pie = gender_dist.plot(kind = "pie", figsize = (3,3), autopct='%1.1f%%')
gender_pie
# Out:
# <AxesSubplot:ylabel='Sex'>

# %%
# Take existing data series and break into lists for pyplot
gender_index = list(gender_dist.index.values)
gender_list = gender_dist.values.tolist()

# Generate a pie plot showing the distribution of female versus male mice using pyplot
labels = gender_index
gender = gender_list
colors = ["royalblue", "darkorange"]
explode = [0, 0]

plt.pie(gender, explode = explode, labels = labels, colors = colors, autopct="%1.1f%%", startangle = 0)
plt.axis("equal")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

regimen_list = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]
regimen_df = duplicates_dropped[duplicates_dropped["Drug Regimen"].isin(regimen_list)]
#regimen_df


# Start by getting the last (greatest) timepoint for each mouse
tumor_volume = duplicates_dropped.groupby("Mouse ID")["Timepoint"].max().reset_index()
tumor_volume

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
final_tumor = pd.merge(tumor_volume, regimen_df, on = ["Mouse ID", "Timepoint"])
final_tumor.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     a203         45           67.973419                 2    Infubinol
# 1     a251         45           65.525743                 1    Infubinol
# 2     a275         45           62.999356                 3     Ceftamin
# 3     a411         45           38.407618                 1     Ramicane
# 4     a444         45           43.047543                 0     Ramicane
#
#       Sex  Age_months  Weight (g)
# 0  Female          20          23
# 1  Female          21          25
# 2  Female          20          28
# 3    Male           3          22
# 4  Female          10          25

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_data = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. Start for loop HERE!

for treatment in treatments:

    # Locate the rows which contain mice on each drug and get the tumor volumes [LOC] (get a series)
    final_tumor_vol = final_tumor.loc[final_tumor["Drug Regimen"] == treatment, "Tumor Volume (mm3)"]        
    
    # add subset (add series into empty list)
    tumor_vol_data.append(final_tumor_vol)
    
    # Determine outliers using upper and lower bounds
    quartiles = final_tumor_vol.quantile([.25, .5, .75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq - lowerq
    lower_bound = lowerq - (1.5 * iqr)
    upper_bound = upperq + (1.5 * iqr)
    potential_outliers = final_tumor_vol.loc[(final_tumor_vol < lower_bound) | (final_tumor_vol > upper_bound)]
    print(f"{treatment}'s potential outliers: {potential_outliers}")
# Out:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers: 15    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
fig1, ax1 = plt.subplots()
ax1.set_title("Final Tumor Size by Treatment")
ax1.set_xlabel("Drug Regimen")
ax1.set_ylabel("Final Tumor Volume (mm3)")
ax1.boxplot(tumor_vol_data, labels = treatments)
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
capomulin_df = duplicates_dropped[duplicates_dropped["Drug Regimen"] == "Capomulin"]
b128 = capomulin_df.loc[capomulin_df["Mouse ID"] == "b128"]

b128.plot(x="Timepoint", y="Tumor Volume (mm3)", title = "Capomulin Treatment of Mouse B128",
         xlabel = "Timepoint (days)", ylabel = "Tumor Volume (mm3)")
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
capomulin_df = duplicates_dropped[duplicates_dropped["Drug Regimen"] == "Capomulin"]
capomulin_mean = capomulin_df.groupby(["Mouse ID"]).mean()[["Weight (g)", "Tumor Volume (mm3)"]]


capomulin_mean.plot(kind = "scatter", x="Weight (g)", y = "Tumor Volume (mm3)", figsize = (6,4),
               title = "Mouse Weight vs. Average Tumor Volume for Capomulin")
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
x_values = capomulin_mean["Weight (g)"]
y_values = capomulin_mean["Tumor Volume (mm3)"]
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (5.8, 0.8), fontsize=15, color="red")
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.show()

print(f"The correlation between mouse weight and the average tumor volume is {slope}.")
# Out:
# The correlation between mouse weight and the average tumor volume is 0.9544396890241049.
